# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("movie.csv")

# %%
data.head()
# Out:
#    mov_id          movie_title  movie_year       dra_time  \
# 0       1       Move to Heaven        2021        52 min.
# 1       2    Hospital Playlist        2020  1 hr. 30 min.
# 2       3       Flower of Evil        2020  1 hr. 10 min.
# 3       4  Hospital Playlist 2        2021  1 hr. 40 min.
# 4       5            My Mister        2018  1 hr. 17 min.
#
#                                                 Cast  \
# 0  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...
# 1  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 2  Lee Joon Gi, Moon Chae Won, Jang Hee Jin, Seo ...
# 3  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 4  Lee Sun Kyun, IU, Park Ho San, Song Sae Byuk, ...
#
#                                      Genre
# 0                   Life,  Drama,  Family
# 1   Friendship,  Romance,  Life,  Medical
# 2  Thriller,  Romance,  Crime,  Melodrama
# 3   Friendship,  Romance,  Life,  Medical
# 4   Psychological,  Life,  Drama,  Family

# %%
movie_genres=[]
mov_id=[]
movie_genres_temp = data['Genre'].values.tolist()
movie_genres_temp1=[]

# %%
for i in data['mov_id']:
    movie_genres.append(movie_genres_temp[i-1].split(","))

# %%
for i in range(len(movie_genres_temp)):
    for j in movie_genres_temp[i].split(","):
        mov_id.append(i)
        movie_genres_temp1.append(j)

# %%
data={"mov_id":mov_id,"movie_genres":movie_genres_temp1}
df = pd.DataFrame(data)
df.head()
# Out:
#    mov_id movie_genres
# 0       0         Life
# 1       0        Drama
# 2       0      Family
# 3       1   Friendship
# 4       1      Romance

# %%
#print(len(pd.unique(df["movie_genres"])))

# %%
df['movie_genres']=df['movie_genres'].str.strip()
df['genre_id'] = pd.factorize(df['movie_genres'])[0]

# %%
print(len(pd.unique(df["genre_id"])))
# Out:
# 26

# %%
df.head(20)
# Out:
#     mov_id   movie_genres  genre_id
# 0        0           Life         0
# 1        0          Drama         1
# 2        0         Family         2
# 3        1     Friendship         3
# 4        1        Romance         4
# 5        1           Life         0
# 6        1        Medical         5
# 7        2       Thriller         6
# 8        2        Romance         4
# 9        2          Crime         7
# 10       2      Melodrama         8
# 11       3     Friendship         3
# 12       3        Romance         4
# 13       3           Life         0
# 14       3        Medical         5
# 15       4  Psychological         9
# 16       4           Life         0
# 17       4          Drama         1
# 18       4         Family         2
# 19       5         Comedy        10

# %%
df[['mov_id', 'genre_id']].to_csv('movie_genres.csv',mode = 'w', index=False)
df[['genre_id','movie_genres']].to_csv('genres_temp.csv',mode = 'w', index=False)

# %%
genreData=pd.read_csv("genres_temp.csv")

# %%
genreData.drop('genre_id',axis=1,inplace=True)

print(genreData)
# Out:
#     movie_genres
# 0           Life
# 1          Drama
# 2         Family
# 3     Friendship
# 4        Romance
# ..           ...
# 391        Drama
# 392     Business
# 393       Comedy
# 394      Romance
# 395       Sports
#
# [396 rows x 1 columns]

# %%
genreData=genreData.drop_duplicates(subset=None, keep="first", inplace=False)

a=genreData['movie_genres'].values.tolist()


genreData.head(20)
# Out:
#      movie_genres
# 0            Life
# 1           Drama
# 2          Family
# 3      Friendship
# 4         Romance
# 6         Medical
# 7        Thriller
# 9           Crime
# 10      Melodrama
# 15  Psychological
# 19         Comedy
# 25          Youth
# 31     Historical
# 32        Mystery
# 41         Sci-Fi
# 46         Action
# 49        Fantasy
# 51            Law
# 54       Military
# 57      Political

# %%
genreData[['movie_genres']].to_csv('genres.csv',mode = 'w', index=False)
print(len(a))
# Out:
# 26

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 data.head()
#
# AttributeError: 'dict' object has no attribute 'head'
